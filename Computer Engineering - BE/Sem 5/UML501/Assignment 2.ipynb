# %%
#creating dataframe
import pandas as pd
data = pd.read_csv("AWCustomers.csv")

# %%
#Q1A
df = pd.DataFrame(data)
df
# Out:
#        CustomerID Title FirstName MiddleName  LastName Suffix  \
# 0           21173   NaN      Chad          C      Yuan    NaN
# 1           13249   NaN      Ryan        NaN     Perry    NaN
# 2           29350   NaN     Julia        NaN  Thompson    NaN
# 3           13503   NaN  Theodore        NaN     Gomez    NaN
# 4           22803   NaN  Marshall          J      Shan    NaN
# ...           ...   ...       ...        ...       ...    ...
# 18356       25414   NaN     Grace          C    Bailey    NaN
# 18357       11459   NaN     Tasha        NaN      Deng    NaN
# 18358       12160   NaN    Jaclyn        NaN     Zhang    NaN
# 18359       14353   NaN      Erin          I      Reed    NaN
# 18360       16676   NaN    Amanda        NaN     Perry    NaN
#
#                  AddressLine1 AddressLine2            City  \
# 0          7090 C. Mount Hood          NaN      Wollongong
# 1         3651 Willow Lake Rd          NaN         Shawnee
# ...

# %%
#Q1B
#filtering out unnecessary columns
dfr = df.filter(['CustomerID','FirstName','LastName','AddressLine1','City','StateProvinceName','CountryRegionName','PostalCode','PhoneNumber','Occupation','Education','HomeOwnerFlag','NumberCarOwned','Gender','MaritalStatus','NumberChildrenAtHome','YearlyIncome'],axis=1)
dfr
# Out:
#        CustomerID FirstName  LastName            AddressLine1            City  \
# 0           21173      Chad      Yuan      7090 C. Mount Hood      Wollongong
# 1           13249      Ryan     Perry     3651 Willow Lake Rd         Shawnee
# 2           29350     Julia  Thompson  1774 Tice Valley Blvd.     West Covina
# 3           13503  Theodore     Gomez         2103 Baldwin Dr       Liverpool
# 4           22803  Marshall      Shan         Am Gallberg 234           Werne
# ...           ...       ...       ...                     ...             ...
# 18356       25414     Grace    Bailey      6627 Camelback Ct.        Coronado
# 18357       11459     Tasha      Deng         9627 Kendall Rd  Port Macquarie
# 18358       12160    Jaclyn     Zhang       4364 Viera Avenue       Beaverton
# 18359       14353      Erin      Reed  3866 Mt. Everest Court       Vancouver
# 18360       16676    Amanda     Perry     7870 Orangewood Dr.       Grossmont
#
# ...

# %% [markdown]
# #### Q1C
# ##### Determining the data types
# ##### HomeOwnerFlag: Nominal
# ##### Gender: Nominal
# ##### HomeOwnerStatus: Nominal
# ##### MaritalStatus: Nominal
# ##### NumberChildrenAtHome: Ordinal
# ##### YearlyIncome: Continous

# %%
#Q2
dfr.describe()
# Out:
#          CustomerID  HomeOwnerFlag  NumberChildrenAtHome   YearlyIncome
# count  18361.000000   18361.000000          18361.000000   18361.000000
# mean   20241.987092       0.610588              0.338162   72754.779642
# std     5336.332731       0.487630              0.568957   30686.014313
# min    11000.000000       0.000000              0.000000   25435.000000
# 25%    15621.000000       0.000000              0.000000   53312.000000
# 50%    20248.000000       1.000000              0.000000   61851.000000
# 75%    24863.000000       1.000000              1.000000   87410.000000
# max    29483.000000       1.000000              3.000000  139115.000000

# %%
dfr.isnull().sum()
#zero nulls in data set
# Out:
# CustomerID              0
# FirstName               0
# LastName                0
# AddressLine1            0
# City                    0
# StateProvinceName       0
# CountryRegionName       0
# PostalCode              0
# PhoneNumber             0
# Occupation              0
# Education               0
# HomeOwnerFlag           0
# Gender                  0
# MaritalStatus           0
# NumberChildrenAtHome    0
# YearlyIncome            0
# dtype: int64

# %%
#normalization
dfr['n_income'] = (dfr['YearlyIncome'] - dfr['YearlyIncome'].min()) / (dfr['YearlyIncome'].max() - dfr['YearlyIncome'].min())

# %%
dfr
# Out:
#        CustomerID FirstName  LastName            AddressLine1            City  \
# 0           21173      Chad      Yuan      7090 C. Mount Hood      Wollongong
# 1           13249      Ryan     Perry     3651 Willow Lake Rd         Shawnee
# 2           29350     Julia  Thompson  1774 Tice Valley Blvd.     West Covina
# 3           13503  Theodore     Gomez         2103 Baldwin Dr       Liverpool
# 4           22803  Marshall      Shan         Am Gallberg 234           Werne
# ...           ...       ...       ...                     ...             ...
# 18356       25414     Grace    Bailey      6627 Camelback Ct.        Coronado
# 18357       11459     Tasha      Deng         9627 Kendall Rd  Port Macquarie
# 18358       12160    Jaclyn     Zhang       4364 Viera Avenue       Beaverton
# 18359       14353      Erin      Reed  3866 Mt. Everest Court       Vancouver
# 18360       16676    Amanda     Perry     7870 Orangewood Dr.       Grossmont
#
# ...

# %%
len(dfr['CountryRegionName'].unique())
# Out:
# 6

# %%
#binning
import matplotlib.pyplot as plt

country = dfr['CountryRegionName']
plt.hist(country,bins=6,color='yellow')
plt.show()

# %%
#binning with respect to number of children at home
print(dfr['NumberChildrenAtHome'].unique())
plt.hist(dfr['NumberChildrenAtHome'],bins = 4,color='yellow')
# Out:
# [0 1 2 3]
# (array([13038.,  4468.,   824.,    31.]),
#  array([0.  , 0.75, 1.5 , 2.25, 3.  ]),
#  <BarContainer object of 4 artists>)

# %%
#binarization
dfr['YearlyIncome'].mean()
from sklearn.preprocessing import Binarizer
salary = dfr.iloc[:, 15].values
salary
y = salary
y = y.reshape(1,-1)
bin = Binarizer(7300)
x = bin.fit_transform(y) 
x
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# c:\Users\shrey\OneDrive\Desktop\SEM 5\Machine Learning\ML Lab Assignment 3 (1).ipynb Cell 14 in <module>
#       <a href='vscode-notebook-cell:/c%3A/Users/shrey/OneDrive/Desktop/SEM%205/Machine%20Learning/ML%20Lab%20Assignment%203%20%281%29.ipynb#X16sZmlsZQ%3D%3D?line=5'>6</a> y = salary
#       <a href='vscode-notebook-cell:/c%3A/Users/shrey/OneDrive/Desktop/SEM%205/Machine%20Learning/ML%20Lab%20Assignment%203%20%281%29.ipynb#X16sZmlsZQ%3D%3D?line=6'>7</a> y = y.reshape(1,-1)
# ----> <a href='vscode-notebook-cell:/c%3A/Users/shrey/OneDrive/Desktop/SEM%205/Machine%20Learning/ML%20Lab%20Assignment%203%20%281%29.ipynb#X16sZmlsZQ%3D%3D?line=7'>8</a> bin = Binarizer(7300)
# ...

# %%
# Q3B
import numpy as np
covariance = np.cov(dfr['YearlyIncome'], dfr['CustomerID'])
stddevx=np.std(dfr['YearlyIncome'])
stddevy=np.std(dfr['CustomerID'])
pearsons_coeff=covariance/(stddevx*stddevy)
pearsons_coeff
# Out:
# array([[ 5.75070694, -0.02942484],
#        [-0.02942484,  0.17391061]])
