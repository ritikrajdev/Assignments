# %%
# QUESTION 1

class eightpuzzleprob:
    def __init__(self, startState, goalState, startState2D, goalState2D):
        self.startState=startState
        self.goalState=goalState
        self.startState2D=startState2D
        self.goalState2D=goalState2D

    def euclidean_distance(self):
        val=0
        for i115 in range(0, 3):
            for j115 in range(0, 3):
                goalNode=self.goalState2D[i115][j115]
                if goalNode==0:
                    continue
                goalIndexX=i115
                goalIndexY=j115
                for k115 in range(0, 3):
                    for l115 in range(0, 3):
                        startNode=self.startState2D[k115][l115]
                        if startNode==goalNode:
                            startIndexX=k115
                            startIndexY=l115
                            break
                x=abs(goalIndexX-startIndexX)
                y=abs(goalIndexY-startIndexY)
                distance=( pow(x, 2) + pow(y, 2))**0.5
                val+=distance
                print("Euclidean distance for " ,goalNode,"is" ,int(distance))
        print("Heuristic function value for Euclidean distance = ",val)
        
    def manhattan_distance(self):
        val=0
        for i115 in range(0, 9):
            goalNode=self.goalState[i115]
            if goalNode==0:
                continue
            goalIndex=i115
            for j115 in range(0, 9):
                startNode=self.startState[j115]
                if startNode==goalNode:
                    startIndex=j115
                    break
            difference=abs(goalIndex-startIndex)
            if difference<3:
                moves=difference
            elif difference>=3 and difference<6:
                moves=difference%3 + 1
            elif difference>=6 and difference<8:
                moves=difference%3 + 2
            val+=moves
            print("Manhattan distance for",self.goalState[i115],"is ",moves)
        print("Heuristic function value for Manhattan distance= ",val)
            
    def minkowski_distance(self):
        val=0
        p=float(input("Enter value of p: "))
        for i115 in range(0, 3):
            for j115 in range(0, 3):
                goalNode=self.goalState2D[i115][j115]
                if goalNode==0:
                    continue
                goalIndexX=i115
                goalIndexY=j115
                for k115 in range(0, 3):
                    for l115 in range(0, 3):
                        startNode=self.startState2D[k115][l115]
                        if startNode==goalNode:
                            startIndexX=k115
                            startIndexY=l115
                            break
                x=abs(goalIndexX-startIndexX)
                y=abs(goalIndexY-startIndexY)
                distance=pow( pow(x, p) + pow(y, p), 1/p )
                val+=distance
                print("Minkowski distance for" ,goalNode ,"is ",int(distance))
        print("Heuristic function value for Minkowski distance= ",val)
        

start=[2, 0, 3, 1, 8, 4, 7, 6, 5]
goal= [1, 2, 3, 8, 0, 4, 7, 6, 5]
start2D=[[2, 0, 3], [1, 8, 4], [7, 6, 5]]
goal2D= [[1, 2, 3], [8, 0, 4], [7, 6, 5]]
problem=eightpuzzleprob(start, goal, start2D, goal2D)
problem.euclidean_distance()
problem.manhattan_distance()
problem.minkowski_distance()
# Out:
# Euclidean distance for  1 is 1
# Euclidean distance for  2 is 1
# Euclidean distance for  3 is 0
# Euclidean distance for  8 is 1
# Euclidean distance for  4 is 0
# Euclidean distance for  7 is 0
# Euclidean distance for  6 is 0
# Euclidean distance for  5 is 0
# Heuristic function value for Euclidean distance =  3.0
# Manhattan distance for 1 is  1
# Manhattan distance for 2 is  1
# Manhattan distance for 3 is  0
# Manhattan distance for 8 is  1
# Manhattan distance for 4 is  0
# Manhattan distance for 7 is  0
# Manhattan distance for 6 is  0
# Manhattan distance for 5 is  0
# Heuristic function value for Manhattan distance=  3
# Minkowski distance for 1 is  1
# Minkowski distance for 2 is  1
# Minkowski distance for 3 is  0
# Minkowski distance for 8 is  1
# Minkowski distance for 4 is  0
# Minkowski distance for 7 is  0
# Minkowski distance for 6 is  0
# Minkowski distance for 5 is  0
# Heuristic function value for Minkowski distance=  3.0

# %%
# QUESTION 2

#2
import copy
class eightpuzzleprob:
    def __init__(self,startState,goalState):
        self.currentState=startState
        self.goalState=goalState
        self.emptyIndex=self.emptyTileIndex()
        self.prevState=None
    def up(self):
        if self.emptyIndex==6 or self.emptyIndex==7 or self.emptyIndex==8:
            print("cannot move")
            return False
        else:
            self.prevState=copy.deepcopy(self)
            self.currentState[self.emptyIndex]=self.currentState[self.emptyIndex+3]
            self.currentState[self.emptyIndex+3]=0
            self.emptyIndex=self.emptyIndex+3
            print('Action Up')
            return True
    def down(self):
        if self.emptyIndex==0 or self.emptyIndex==1 or self.emptyIndex==2:
            print("cannot move")
            return False
        else:
            self.prevState=copy.deepcopy(self)
            self.currentState[self.emptyIndex]=self.currentState[self.emptyIndex-3]
            self.currentState[self.emptyIndex-3]=0
            self.emptyIndex=self.emptyIndex-3
            print('Action down')
            return True
    def left(self):
        if self.emptyIndex==2 or self.emptyIndex==5 or self.emptyIndex==8:
            print('cannot move')
            return False
        else:
            self.prevState=copy.deepcopy(self)
            self.currentState[self.emptyIndex]=self.currentState[self.emptyIndex+1]
            self.currentState[self.emptyIndex+1]=0
            self.emptyIndex=self.emptyIndex+1
            print('Action left')
            return True
    def right(self):
        if self.emptyIndex==0 or self.emptyIndex==3 or self.emptyIndex==6:
            print('cannot move')
            return False
        else:
            self.prevState=copy.deepcopy(self)
            self.currentState[self.emptyIndex]=self.currentState[self.emptyIndex-1]
            self.currentState[self.emptyIndex-1]=0
            self.emptyIndex=self.emptyIndex-1
            print('Action right')
            return True
    def emptyTileIndex(self):
        for i115 in range(0,9):
            if(self.currentState[i115]==0):
                return i115
    def isGoalReached(self):
        if(self.currentState==self.goalState):
            return True
        else:
            return False
    def displayState(self):
        print('-------------------')
        for i115 in range(0,8,3):
            print(self.currentState[i115],self.currentState[i115+1],self.currentState[i115+2])
        print('-------------------')
    def __eq__(self,other):
        return self.currentState==other.currentState
    
    def possible_nextstates(self):
        stateList=[]
        left_state=copy.deepcopy(self)
        if left_state.left():
            stateList.append(left_state)
        right_state=copy.deepcopy(self)
        if right_state.right():
            stateList.append(right_state)
        up_state=copy.deepcopy(self)
        if up_state.up():
            stateList.append(up_state)
        down_state=copy.deepcopy(self)
        if down_state.down():
            stateList.append(down_state)
        return stateList
def heuristic(self):
    cnt=0
    for i115 in range(0,9):
        if self.goalState[i115]!=0 and self.goalState[i115]!=self.currentState[i115]:
            cnt=cnt+1
    return cnt

def BestFirstSearch(startState):
    isopen=[]
    closed=[]
    nextStates=[]
    isopen.append(startState)
    while isopen:
        thisState=isopen.pop(0)
        thisState.displayState()
        print('Value of heuristic :',heuristic(thisState))
        if thisState not in closed:
            closed.append(thisState)
            if thisState.isGoalReached():
                print('Goal state is found ..stopping search')
                constructPath(thisState)
                break
            nextStates=thisState.possible_nextstates()
            for eachstate in nextStates:
                if eachstate not in closed and eachstate not in isopen:
                    isopen.append(eachstate)
                    isopen.sort(key=heuristic)
                    
def constructPath(gstate):
    print('The solution path from ----goal to start----')
    while gstate is not None:
        gstate.displayState()
        gstate=gstate.prevState

start=[2,0,3,1,8,4,7,6,5]
goal=[1,2,3,8,0,4,7,6,5]
problem=eightpuzzleprob(start,goal)
BestFirstSearch(problem)
# Out:
# -------------------
# 2 0 3
# 1 8 4
# 7 6 5
# -------------------
# Value of heuristic : 3
# Action left
# Action right
# Action Up
# cannot move
# -------------------
# 0 2 3
# 1 8 4
# 7 6 5
# -------------------
# Value of heuristic : 2
# Action left
# cannot move
# Action Up
# cannot move
# -------------------
# 1 2 3
# 0 8 4
# 7 6 5
# -------------------
# Value of heuristic : 1
# Action left
# cannot move
# Action Up
# Action down
# -------------------
# 1 2 3
# 8 0 4
# 7 6 5
# -------------------
# Value of heuristic : 0
# Goal state is found ..stopping search
# The solution path from ----goal to start----
# -------------------
# 1 2 3
# 8 0 4
# 7 6 5
# -------------------
# -------------------
# 1 2 3
# 0 8 4
# 7 6 5
# -------------------
# -------------------
# 0 2 3
# 1 8 4
# 7 6 5
# -------------------
# -------------------
# 2 0 3
# 1 8 4
# 7 6 5
# -------------------

# %%
#  QUESTION 3

import copy
class eightpuzzleprob:
    def __init__(self,startState,goalState):
        self.currentState=startState
        self.goalState=goalState
        self.emptyIndex=self.emptyTileIndex()
        self.prevState=None
    def up(self):
        if self.emptyIndex==6 or self.emptyIndex==7 or self.emptyIndex==8:
            print("cannot move")
            return False
        else:
            self.prevState=copy.deepcopy(self)
            self.currentState[self.emptyIndex]=self.currentState[self.emptyIndex+3]
            self.currentState[self.emptyIndex+3]=0
            self.emptyIndex=self.emptyIndex+3
            print('Action Up')
            return True
    def down(self):
        if self.emptyIndex==0 or self.emptyIndex==1 or self.emptyIndex==2:
            print("cannot move")
            return False
        else:
            self.prevState=copy.deepcopy(self)
            self.currentState[self.emptyIndex]=self.currentState[self.emptyIndex-3]
            self.currentState[self.emptyIndex-3]=0
            self.emptyIndex=self.emptyIndex-3
            print('Action down')
            return True
    def left(self):
        if self.emptyIndex==2 or self.emptyIndex==5 or self.emptyIndex==8:
            print('cannot move')
            return False
        else:
            self.prevState=copy.deepcopy(self)
            self.currentState[self.emptyIndex]=self.currentState[self.emptyIndex+1]
            self.currentState[self.emptyIndex+1]=0
            self.emptyIndex=self.emptyIndex+1
            print('Action left')
            return True
    def right(self):
        if self.emptyIndex==0 or self.emptyIndex==3 or self.emptyIndex==6:
            print('cannot move')
            return False
        else:
            self.prevState=copy.deepcopy(self)
            self.currentState[self.emptyIndex]=self.currentState[self.emptyIndex-1]
            self.currentState[self.emptyIndex-1]=0
            self.emptyIndex=self.emptyIndex-1
            print('Action right')
            return True
    def emptyTileIndex(self):
        for i115 in range(0,9):
            if(self.currentState[i115]==0):
                return i115
    def isGoalReached(self):
        if(self.currentState==self.goalState):
            return True
        else:
            return False
    def displayState(self):
        print('-------------------')
        for i115 in range(0,8,3):
            print(self.currentState[i115],self.currentState[i115+1],self.currentState[i115+2])
        print('-------------------')
    def __eq__(self,other):
        return self.currentState==other.currentState
    
    def possible_nextstates(self):
        stateList=[]
        left_state=copy.deepcopy(self)
        if left_state.left():
            stateList.append(left_state)
        right_state=copy.deepcopy(self)
        if right_state.right():
            stateList.append(right_state)
        up_state=copy.deepcopy(self)
        if up_state.up():
            stateList.append(up_state)
        down_state=copy.deepcopy(self)
        if down_state.down():
            stateList.append(down_state)
        return stateList
    def heuristic(self):
        cnt=0
        for i115 in range(0,9):
            if self.goalState[i115]!=0 and self.goalState[i115]!=self.currentState[i115]:
                cnt=cnt+1
        return cnt


def HillClimbing(startState):
    isopen=[]
    closed=[]
    nextStates=[]
    isopen.append(startState)
    while isopen:
        thisState=isopen.pop(0)
        thisState.displayState()
        print('Value of heuristic :',heuristic(thisState))
        if thisState not in closed:
            closed.append(thisState)
            if thisState.isGoalReached():
                print('Goal state is found ..stopping search')
                constructPath(thisState)
                break
            nextStates=thisState.possible_nextstates()
            for eachstate in nextStates:
                if eachstate not in closed and eachstate not in isopen:
                    if eachstate.heuristic() < thisState.heuristic():
                        isopen.append(eachstate)
                        closed.append(thisState)
                    
def constructPath(gstate):
    print('The solution path from ----goal to start----')
    while gstate is not None:
        gstate.displayState()
        gstate=gstate.prevState

start=[2,0,3,1,8,4,7,6,5]
goal=[1,2,3,8,0,4,7,6,5]
problem=eightpuzzleprob(start,goal)
HillClimbing(problem)
# Out:
# -------------------
# 2 0 3
# 1 8 4
# 7 6 5
# -------------------
# Value of heuristic : 3
# Action left
# Action right
# Action Up
# cannot move
# -------------------
# 0 2 3
# 1 8 4
# 7 6 5
# -------------------
# Value of heuristic : 2
# Action left
# cannot move
# Action Up
# cannot move
# -------------------
# 1 2 3
# 0 8 4
# 7 6 5
# -------------------
# Value of heuristic : 1
# Action left
# cannot move
# Action Up
# Action down
# -------------------
# 1 2 3
# 8 0 4
# 7 6 5
# -------------------
# Value of heuristic : 0
# Goal state is found ..stopping search
# The solution path from ----goal to start----
# -------------------
# 1 2 3
# 8 0 4
# 7 6 5
# -------------------
# -------------------
# 1 2 3
# 0 8 4
# 7 6 5
# -------------------
# -------------------
# 0 2 3
# 1 8 4
# 7 6 5
# -------------------
# -------------------
# 2 0 3
# 1 8 4
# 7 6 5
# -------------------

# %%
#  QUESTION 4

import copy
class eightpuzzleprob:
    def __init__(self,startState,goalState):
        self.currentState=startState
        self.goalState=goalState
        self.emptyIndex=self.emptyTileIndex()
        self.prevState=None
    def up(self):
        if self.emptyIndex==6 or self.emptyIndex==7 or self.emptyIndex==8:
            print("cannot move")
            return False
        else:
            self.prevState=copy.deepcopy(self)
            self.currentState[self.emptyIndex]=self.currentState[self.emptyIndex+3]
            self.currentState[self.emptyIndex+3]=0
            self.emptyIndex=self.emptyIndex+3
            print('Action Up')
            return True
    def down(self):
        if self.emptyIndex==0 or self.emptyIndex==1 or self.emptyIndex==2:
            print("cannot move")
            return False
        else:
            self.prevState=copy.deepcopy(self)
            self.currentState[self.emptyIndex]=self.currentState[self.emptyIndex-3]
            self.currentState[self.emptyIndex-3]=0
            self.emptyIndex=self.emptyIndex-3
            print('Action down')
            return True
    def left(self):
        if self.emptyIndex==2 or self.emptyIndex==5 or self.emptyIndex==8:
            print('cannot move')
            return False
        else:
            self.prevState=copy.deepcopy(self)
            self.currentState[self.emptyIndex]=self.currentState[self.emptyIndex+1]
            self.currentState[self.emptyIndex+1]=0
            self.emptyIndex=self.emptyIndex+1
            print('Action left')
            return True
    def right(self):
        if self.emptyIndex==0 or self.emptyIndex==3 or self.emptyIndex==6:
            print('cannot move')
            return False
        else:
            self.prevState=copy.deepcopy(self)
            self.currentState[self.emptyIndex]=self.currentState[self.emptyIndex-1]
            self.currentState[self.emptyIndex-1]=0
            self.emptyIndex=self.emptyIndex-1
            print('Action right')
            return True
    def emptyTileIndex(self):
        for i115 in range(0,9):
            if(self.currentState[i115]==0):
                return i115
    def isGoalReached(self):
        if(self.currentState==self.goalState):
            return True
        else:
            return False
    def displayState(self):
        print('-------------------')
        for i115 in range(0,8,3):
            print(self.currentState[i115],self.currentState[i115+1],self.currentState[i115+2])
        print('-------------------')
    def __eq__(self,other):
        return self.currentState==other.currentState
    
    def possible_nextstates(self):
        stateList=[]
        left_state=copy.deepcopy(self)
        if left_state.left():
            stateList.append(left_state)
        right_state=copy.deepcopy(self)
        if right_state.right():
            stateList.append(right_state)
        up_state=copy.deepcopy(self)
        if up_state.up():
            stateList.append(up_state)
        down_state=copy.deepcopy(self)
        if down_state.down():
            stateList.append(down_state)
        return stateList
    
def heuristic_manhattan(self):
    sum=0
    for i115 in range(0, 9):
        goalNode=self.goalState[i115]
        if goalNode==0:
            continue
        goalIndex=i115
        for j115 in range(0, 9):
            currentNode=self.currentState[j115]
            if currentNode==goalNode:
                currentIndex=j115
                break
        diff=abs(goalIndex-currentIndex)
        if diff<3:
            moves=diff
        elif diff>=3 and diff<6:
            moves=diff%3 + 1
        elif diff>=6 and diff<8:
            moves=difference%3 +2
        sum+=moves
        return sum


def BestFirstSearch(startState):
    isopen=[]
    closed=[]
    nextStates=[]
    isopen.append(startState)
    while isopen:
        thisState=isopen.pop(0)
        thisState.displayState()
        print('Value of heuristic :',heuristic_manhattan(thisState))
        if thisState not in closed:
            closed.append(thisState)
            if thisState.isGoalReached():
                print('Goal state is found ..stopping search')
                constructPath(thisState)
                break
            nextStates=thisState.possible_nextstates()
            for eachstate in nextStates:
                if eachstate not in closed and eachstate not in isopen:
                    isopen.append(eachstate)
                    isopen.sort(key=heuristic_manhattan)
                    
def constructPath(gstate):
    print('The solution path from ----goal to start----')
    while gstate is not None:
        gstate.displayState()
        gstate=gstate.prevState
start=[2,0,3,1,8,4,7,6,5]
goal=[1,2,3,8,0,4,7,6,5]
problem=eightpuzzleprob(start,goal)
BestFirstSearch(problem)
# Out:
# -------------------
# 2 0 3
# 1 8 4
# 7 6 5
# -------------------
# Value of heuristic : 1
# Action left
# Action right
# Action Up
# cannot move
# -------------------
# 2 3 0
# 1 8 4
# 7 6 5
# -------------------
# Value of heuristic : 1
# cannot move
# Action right
# Action Up
# cannot move
# -------------------
# 0 2 3
# 1 8 4
# 7 6 5
# -------------------
# Value of heuristic : 1
# Action left
# cannot move
# Action Up
# cannot move
# -------------------
# 1 2 3
# 0 8 4
# 7 6 5
# -------------------
# Value of heuristic : 0
# Action left
# cannot move
# Action Up
# Action down
# -------------------
# 1 2 3
# 8 0 4
# 7 6 5
# -------------------
# Value of heuristic : 0
# Goal state is found ..stopping search
# The solution path from ----goal to start----
# -------------------
# 1 2 3
# 8 0 4
# 7 6 5
# -------------------
# -------------------
# 1 2 3
# 0 8 4
# 7 6 5
# -------------------
# -------------------
# 0 2 3
# 1 8 4
# 7 6 5
# -------------------
# -------------------
# 2 0 3
# 1 8 4
# 7 6 5
# -------------------

# %%
# QUESTION 5

import copy
class ShortestPath:
    def __init__(self, thisMap, startCity, goalCity):
        ShortestPath.thisMap=thisMap
        self.currentCity=startCity
        self.goalCity=goalCity
        self.visitedList=[]
        self.cost=0
        self.visitedList=[]
        self.visitedList.append(self.currentCity)
        self.prevState=None
        
    def displayState(self):
        print('-------------')
        print('current city:',self.currentCity,"Cost:",self.cost)
        print('Visited Cities:',self.visitedList)
        print('-------------')
    
    def __eq__(self, other):
        return self.visitedList==other.visitedList
    
    def __lt__(self, other):
        return self.cost<other.cost

    def __gt__(self, other):
        return self.cost>other.cost
    
    def isGoalReached(self):
        if self.goalCity in self.visitedList:
            return True
        else:
            return False
        
    def move(self,city):
        if(city!=self.currentCity and city not in self.visitedList):
            self.prevState=copy.deepcopy(self)
            print("moving from city",self.currentCity,"to",city)
            self.cost=self.cost+ShortestPath.thisMap[self.currentCity][city]
            self.currentCity=city
            self.visitedList.append(city)
            return True
        else:
            print('Already Visited',city)
            return False
        
    def isGoalReached(self):
        if len(ShortestPath.thisMap[0])==len(self.visitedList):
            return True
        else:
            return False
        
    def possibleNextStates(self):
        stateList=[]
        for i in range(0,4):
            newState=copy.deepcopy(self)
            if newState.move(i):
                stateList.append(newState)
        return stateList

isopen=[]
closed=[]
def UCS(state):
    isopen.append(state)
    while isopen:
        thisState=isopen.pop(0)
        thisState.displayState()
        if thisState not in closed:
            closed.append(thisState)
            if thisState.isGoalReached():
                print("Goal state found.. stopping search")
                constructPath(thisState)
                break
            else:
                nextStates=thisState.possibleNextStates()
                for eachState in nextStates:
                    if eachState not in isopen and eachState not in closed:
                        isopen.append(eachState)
                        isopen.sort()
                    elif eachState in isopen:
                        index=isopen.index(eachState)
                        if isopen[index].cost>eachState.cost:
                            isopen.pop(index)
                            isopen.append(eachState)
                            isopen.sort()
                    elif eachState in closed:
                        index=closed.index(eachState)
                        if closed[index].cost>eachState.cost:
                            closed.pop(index)
                            closed.append(eachState)
                            propogateImprovement(eachState)

def propogateImprovement(state):
    nextStates=state.possibleNextStates()
    for eachState in nextStates:
        if eachState in isopen:
            index=isopen.index[eachState]
            if isopen[index].cost>eachState.cost:
                isopen.pop(index)
                isopen.append(eachState)
                isopen.sort()
            if eachState in closed:
                index=closed.index(eachState)
                if closed[index].cost>eachState.cost:
                    closed.pop(index)
                    closed.append(eachState)
                    propogateImprovement(eachState)

thisMap=[[0, 1, 5, 15, 0], [1, 0, 0, 0, 10], [5, 0, 0, 0, 5], [15, 0, 0, 0, 5], [0, 10, 5, 5, 0]]
startState=0
goalState=4
problem=ShortestPath(thisMap, startState, goalState)
UCS(problem)
# Out:
# -------------
# current city: 0 Cost: 0
# Visited Cities: [0]
# -------------
# Already Visited 0
# moving from city 0 to 1
# moving from city 0 to 2
# moving from city 0 to 3
# -------------
# current city: 1 Cost: 1
# Visited Cities: [0, 1]
# -------------
# Already Visited 0
# Already Visited 1
# moving from city 1 to 2
# moving from city 1 to 3
# -------------
# current city: 2 Cost: 1
# Visited Cities: [0, 1, 2]
# -------------
# Already Visited 0
# Already Visited 1
# Already Visited 2
# moving from city 2 to 3
# -------------
# current city: 3 Cost: 1
# Visited Cities: [0, 1, 3]
# -------------
# Already Visited 0
# Already Visited 1
# moving from city 3 to 2
# Already Visited 3
# -------------
# current city: 3 Cost: 1
# Visited Cities: [0, 1, 2, 3]
# -------------
# Already Visited 0
# Already Visited 1
# Already Visited 2
# Already Visited 3
# -------------
# current city: 2 Cost: 1
# Visited Cities: [0, 1, 3, 2]
# -------------
# Already Visited 0
# Already Visited 1
# Already Visited 2
# Already Visited 3
# -------------
# current city: 2 Cost: 5
# Visited Cities: [0, 2]
# -------------
# Already Visited 0
# moving from city 2 to 1
# Already Visited 2
# moving from city 2 to 3
# -------------
# current city: 1 Cost: 5
# Visited Cities: [0, 2, 1]
# -------------
# Already Visited 0
# Already Visited 1
# Already Visited 2
# moving from city 1 to 3
# -------------
# current city: 3 Cost: 5
# Visited Cities: [0, 2, 3]
# -------------
# Already Visited 0
# moving from city 3 to 1
# Already Visited 2
# Already Visited 3
# -------------
# current city: 3 Cost: 5
# Visited Cities: [0, 2, 1, 3]
# -------------
# Already Visited 0
# Already Visited 1
# Already Visited 2
# Already Visited 3
# -------------
# current city: 1 Cost: 5
# Visited Cities: [0, 2, 3, 1]
# -------------
# Already Visited 0
# Already Visited 1
# Already Visited 2
# Already Visited 3
# -------------
# current city: 3 Cost: 15
# Visited Cities: [0, 3]
# -------------
# Already Visited 0
# moving from city 3 to 1
# moving from city 3 to 2
# Already Visited 3
# -------------
# current city: 1 Cost: 15
# Visited Cities: [0, 3, 1]
# -------------
# Already Visited 0
# Already Visited 1
# moving from city 1 to 2
# Already Visited 3
# -------------
# current city: 2 Cost: 15
# Visited Cities: [0, 3, 2]
# -------------
# Already Visited 0
# moving from city 2 to 1
# Already Visited 2
# Already Visited 3
# -------------
# current city: 2 Cost: 15
# Visited Cities: [0, 3, 1, 2]
# -------------
# Already Visited 0
# Already Visited 1
# Already Visited 2
# Already Visited 3
# -------------
# current city: 1 Cost: 15
# Visited Cities: [0, 3, 2, 1]
# -------------
# Already Visited 0
# Already Visited 1
# Already Visited 2
# Already Visited 3
